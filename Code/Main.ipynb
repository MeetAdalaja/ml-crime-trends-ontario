# %%
# !pip install lightgbm
# !pip install xgboost
# !pip install matplotlib scikit-learn pandas


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import ElasticNet


# Load dataset
df = pd.read_csv("Merged_Unemployment_Data.csv")

# Convert date column to datetime
df['REF_DATE'] = pd.to_datetime(df['REF_DATE'], format='%Y')
# REF_DATE as index
df.set_index('REF_DATE', inplace=True)

violations = [
    'Total robbery [160]',
    'Total property crime violations [200]',
    'Total theft under $5,000 (non-motor vehicle) [240]',
    'Total theft of motor vehicle [220]',
    'Total mischief [250]',
    'Total drug violations [401]',
    # 'Murder, first degree [1110]',
    # 'Murder, second degree [1120]',
    "Sexual assault, level 3, aggravated [1310]",
    'Abduction under age 14, by parent or guardian [1560]',
    'Criminal harassment [1625]'
]

Place = 'Ontario [35]'


def plot_combined_predictions(X_train_scaled, y_train, X_test_scaled, y_test, title_suffix, place_name):
    models = {
        "Random Forest": RandomForestRegressor(),
        "Decision Tree": DecisionTreeRegressor(random_state=42),
        # "Neural Net (MLP)": MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', max_iter=1000, random_state=42),
        "XGBoost": XGBRegressor(),
        # "LightGBM": LGBMRegressor(n_estimators=500, max_depth=7, learning_rate=0.05, num_leaves=31, min_child_samples=5),
        "Ridge Regression": Ridge(),
        "Elastic Net": ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42),
        "Extra Trees": ExtraTreesRegressor()
    }

    predictions = {}

    for name, model in models.items():
        model.fit(X_train_scaled, y_train.values.ravel())
        y_pred = model.predict(X_test_scaled)
        predictions[name] = pd.Series(y_pred, index=y_test.index)

        # Print metrics
        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test, y_pred)
        accuracy = 100 - (mae / np.mean(y_test) * 100)

        print(f"{name} ({title_suffix}):")
        print(f"  MAE={mae:.2f}, MSE={mse:.2f}, RMSE={rmse:.2f}, R²={r2:.3f}, Accuracy={accuracy:.2f}%")

    # Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(y_train, label='Training Data')
    plt.plot(y_test, label='Actual Test Data', linewidth=2, color='black')

    for name, y_pred_series in predictions.items():
        plt.plot(y_pred_series, label=f'Predicted: {name}')

    plt.title(f'Combined Model Predictions - {title_suffix}')
    plt.suptitle(place_name)
    plt.xlabel('Year')
    plt.ylabel('Actual_incidents')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()



for vio in violations:
    print(f"\n--- Evaluating: {vio} ---")
    
    filtered_df = df[(df['GEO'] == Place) & (df['Violations'] == vio)]
    y_full = filtered_df[['Actual_incidents']]
    X_full = filtered_df[[
        'Rate_per_100000_population',
        'Cleared_by_charge', 'Cleared_otherwise',
        'Percentage_contribution_to_the_Crime_Severity_Index_(CSI)',
        'Rate_adult_charged_per_100000_population_aged_18_years_and_over',
        'Rate_total_persons_charged_per_100000_population_aged_12_years_and_over',
        'Rate_youth_charged_per_100000_population_aged_12_to_17_years',
        'Rate_youth_not_charged_per_100000_population_aged_12_to_17_years',
        'Total_cleared', 'Total_adult_charged', 'Total_persons_charged',
        'Total_youth_charged', 'Total_youth_not_charged'
    ]]

    # ========== General Evaluation ==========
    y_train3 = y_full['1998-01-01':'2019-12-31']
    y_test3 = y_full['2019-01-01':'2023-12-31']
    X_train = X_full['1998-01-01':'2019-12-31']
    X_test = X_full['2019-01-01':'2023-12-31']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    plot_combined_predictions(X_train_scaled, y_train3, X_test_scaled, y_test3, f"{vio} (Train till 2019, Test 2020–2023)", Place)

    # ========== Additional Cases for Drug Violations ==========
    if vio == 'Total drug violations [401]':
        # --- Case 1: Train till 2016, Test 2016–2023 ---
        y_train_1 = y_full['1998-01-01':'2016-12-31']
        y_test_1 = y_full['2016-01-01':'2023-12-31']
        X_train_1 = X_full['1998-01-01':'2016-12-31']
        X_test_1 = X_full['2016-01-01':'2023-12-31']

        scaler_1 = StandardScaler()
        X_train_1_scaled = scaler_1.fit_transform(X_train_1)
        X_test_1_scaled = scaler_1.transform(X_test_1)

        plot_combined_predictions(X_train_1_scaled, y_train_1, X_test_1_scaled, y_test_1,
                                  f"{vio} (Train till 2016, Test 2016–2023)", Place)

        # --- Case 2: Train till 2016, Test 2016–2018 ---
        y_test_2 = y_full['2016-01-01':'2018-12-31']
        X_test_2 = X_full['2016-01-01':'2018-12-31']
        X_test_2_scaled = scaler_1.transform(X_test_2)  # use same scaler

        plot_combined_predictions(X_train_1_scaled, y_train_1, X_test_2_scaled, y_test_2,
                                  f"{vio} (Train till 2016, Test 2016–2018)", Place)
# Out:
# --- Evaluating: Total robbery [160] ---
# Random Forest (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=658.58, MSE=692544.72, RMSE=832.19, R²=0.110, Accuracy=91.48%
# Decision Tree (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=530.80, MSE=455458.80, RMSE=674.88, R²=0.415, Accuracy=93.13%
# XGBoost (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=514.60, MSE=429448.92, RMSE=655.32, R²=0.448, Accuracy=93.34%
# Ridge Regression (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=161.10, MSE=44537.28, RMSE=211.04, R²=0.943, Accuracy=97.92%
# Elastic Net (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=139.83, MSE=25250.35, RMSE=158.90, R²=0.968, Accuracy=98.19%
# Extra Trees (Total robbery [160] (Train till 2019, Test 2020–2023)):
#   MAE=432.56, MSE=430534.08, RMSE=656.15, R²=0.447, Accuracy=94.41%
# --- Evaluating: Total property crime violations [200] ---
# Random Forest (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=33651.82, MSE=1865571399.65, RMSE=43192.26, R²=-0.506, Accuracy=91.20%
# Decision Tree (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=30279.60, MSE=1750054862.00, RMSE=41833.66, R²=-0.413, Accuracy=92.08%
# XGBoost (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=18410.56, MSE=741620426.73, RMSE=27232.71, R²=0.401, Accuracy=95.19%
# Ridge Regression (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=61494.28, MSE=4582550653.07, RMSE=67694.54, R²=-2.700, Accuracy=83.92%
# Elastic Net (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=85638.87, MSE=8717015824.09, RMSE=93364.96, R²=-6.038, Accuracy=77.61%
# Extra Trees (Total property crime violations [200] (Train till 2019, Test 2020–2023)):
#   MAE=17821.93, MSE=888659676.74, RMSE=29810.40, R²=0.283, Accuracy=95.34%
# --- Evaluating: Total theft under $5,000 (non-motor vehicle) [240] ---
# Random Forest (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=13335.96, MSE=220361551.30, RMSE=14844.58, R²=0.529, Accuracy=92.51%
# Decision Tree (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=8821.20, MSE=146605478.80, RMSE=12108.07, R²=0.686, Accuracy=95.04%
# XGBoost (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=8196.48, MSE=125532357.87, RMSE=11204.12, R²=0.732, Accuracy=95.40%
# Ridge Regression (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=10853.86, MSE=145867753.22, RMSE=12077.57, R²=0.688, Accuracy=93.90%
# Elastic Net (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=18556.13, MSE=460401560.48, RMSE=21456.97, R²=0.015, Accuracy=89.58%
# Extra Trees (Total theft under $5,000 (non-motor vehicle) [240] (Train till 2019, Test 2020–2023)):
#   MAE=11616.68, MSE=182191792.18, RMSE=13497.84, R²=0.610, Accuracy=93.47%
# --- Evaluating: Total theft of motor vehicle [220] ---
# Random Forest (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=6039.51, MSE=73764919.04, RMSE=8588.65, R²=-0.120, Accuracy=80.76%
# Decision Tree (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=2192.20, MSE=10266306.60, RMSE=3204.11, R²=0.844, Accuracy=93.02%
# XGBoost (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=5229.62, MSE=40207348.64, RMSE=6340.93, R²=0.389, Accuracy=83.34%
# Ridge Regression (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=4351.47, MSE=38577368.03, RMSE=6211.07, R²=0.414, Accuracy=86.14%
# Elastic Net (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=7052.17, MSE=94508239.82, RMSE=9721.53, R²=-0.435, Accuracy=77.54%
# Extra Trees (Total theft of motor vehicle [220] (Train till 2019, Test 2020–2023)):
#   MAE=6011.72, MSE=73179423.27, RMSE=8554.50, R²=-0.111, Accuracy=80.85%
# --- Evaluating: Total mischief [250] ---
# Random Forest (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=1059.71, MSE=1816697.03, RMSE=1347.85, R²=0.397, Accuracy=98.08%
# Decision Tree (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=2145.80, MSE=7418043.00, RMSE=2723.61, R²=-1.463, Accuracy=96.12%
# XGBoost (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=2199.04, MSE=8236854.99, RMSE=2869.99, R²=-1.735, Accuracy=96.03%
# Ridge Regression (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=7698.89, MSE=63202834.31, RMSE=7950.02, R²=-19.989, Accuracy=86.08%
# Elastic Net (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=6406.57, MSE=44893542.66, RMSE=6700.26, R²=-13.909, Accuracy=88.42%
# Extra Trees (Total mischief [250] (Train till 2019, Test 2020–2023)):
#   MAE=974.79, MSE=2205264.35, RMSE=1485.01, R²=0.268, Accuracy=98.24%
# --- Evaluating: Total drug violations [401] ---
# Random Forest (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=4382.18, MSE=21871749.42, RMSE=4676.72, R²=-4.678, Accuracy=67.02%
# Decision Tree (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=1648.60, MSE=5297280.20, RMSE=2301.58, R²=-0.375, Accuracy=87.59%
# XGBoost (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=1648.60, MSE=5297282.51, RMSE=2301.58, R²=-0.375, Accuracy=87.59%
# Ridge Regression (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=1142.99, MSE=1532085.96, RMSE=1237.77, R²=0.602, Accuracy=91.40%
# Elastic Net (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=2430.99, MSE=6166601.06, RMSE=2483.26, R²=-0.601, Accuracy=81.71%
# Extra Trees (Total drug violations [401] (Train till 2019, Test 2020–2023)):
#   MAE=2057.49, MSE=6227280.58, RMSE=2495.45, R²=-0.617, Accuracy=84.52%
# Random Forest (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=6855.60, MSE=69876019.80, RMSE=8359.19, R²=-1.502, Accuracy=59.95%
# Decision Tree (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=6022.38, MSE=54976225.12, RMSE=7414.60, R²=-0.968, Accuracy=64.81%
# XGBoost (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=6065.01, MSE=55097922.78, RMSE=7422.80, R²=-0.973, Accuracy=64.57%
# Ridge Regression (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=1296.46, MSE=2613571.75, RMSE=1616.65, R²=0.906, Accuracy=92.43%
# Elastic Net (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=2329.36, MSE=7930686.87, RMSE=2816.15, R²=0.716, Accuracy=86.39%
# Extra Trees (Total drug violations [401] (Train till 2016, Test 2016–2023)):
#   MAE=6010.14, MSE=56346254.61, RMSE=7506.41, R²=-1.018, Accuracy=64.89%
# Random Forest (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=980.69, MSE=2354280.84, RMSE=1534.37, R²=0.195, Accuracy=95.83%
# Decision Tree (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=831.00, MSE=1035901.67, RMSE=1017.79, R²=0.646, Accuracy=96.46%
# XGBoost (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=944.67, MSE=1360190.79, RMSE=1166.27, R²=0.535, Accuracy=95.98%
# Ridge Regression (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=103.88, MSE=11363.93, RMSE=106.60, R²=0.996, Accuracy=99.56%
# Elastic Net (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=335.08, MSE=124324.47, RMSE=352.60, R²=0.958, Accuracy=98.57%
# Extra Trees (Total drug violations [401] (Train till 2016, Test 2016–2018)):
#   MAE=522.81, MSE=605558.37, RMSE=778.18, R²=0.793, Accuracy=97.77%
# --- Evaluating: Sexual assault, level 3, aggravated [1310] ---
# Random Forest (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=0.99, MSE=1.67, RMSE=1.29, R²=0.701, Accuracy=96.89%
# Decision Tree (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=2.40, MSE=14.40, RMSE=3.79, R²=-1.571, Accuracy=92.50%
# XGBoost (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=3.61, MSE=18.72, RMSE=4.33, R²=-2.343, Accuracy=88.71%
# Ridge Regression (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=0.72, MSE=0.55, RMSE=0.74, R²=0.902, Accuracy=97.74%
# Elastic Net (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=1.97, MSE=4.52, RMSE=2.13, R²=0.193, Accuracy=93.84%
# Extra Trees (Sexual assault, level 3, aggravated [1310] (Train till 2019, Test 2020–2023)):
#   MAE=0.90, MSE=1.94, RMSE=1.39, R²=0.653, Accuracy=97.17%
# --- Evaluating: Abduction under age 14, by parent or guardian [1560] ---
# Random Forest (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=0.71, MSE=0.82, RMSE=0.91, R²=0.760, Accuracy=96.33%
# Decision Tree (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=1.60, MSE=3.60, RMSE=1.90, R²=-0.047, Accuracy=91.75%
# XGBoost (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=0.75, MSE=1.03, RMSE=1.02, R²=0.700, Accuracy=96.14%
# Ridge Regression (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=2.29, MSE=6.75, RMSE=2.60, R²=-0.963, Accuracy=88.19%
# Elastic Net (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=3.92, MSE=22.44, RMSE=4.74, R²=-5.523, Accuracy=79.80%
# Extra Trees (Abduction under age 14, by parent or guardian [1560] (Train till 2019, Test 2020–2023)):
#   MAE=0.40, MSE=0.29, RMSE=0.54, R²=0.917, Accuracy=97.96%
# --- Evaluating: Criminal harassment [1625] ---
# Random Forest (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=1578.08, MSE=3090689.04, RMSE=1758.04, R²=-2.799, Accuracy=84.73%
# Decision Tree (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=1386.40, MSE=2682987.60, RMSE=1637.98, R²=-2.298, Accuracy=86.58%
# XGBoost (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=1145.37, MSE=1874941.80, RMSE=1369.29, R²=-1.304, Accuracy=88.92%
# Ridge Regression (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=623.53, MSE=413059.50, RMSE=642.70, R²=0.492, Accuracy=93.97%
# Elastic Net (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=1473.92, MSE=2312040.42, RMSE=1520.54, R²=-1.842, Accuracy=85.74%
# Extra Trees (Criminal harassment [1625] (Train till 2019, Test 2020–2023)):
#   MAE=1323.02, MSE=2458954.55, RMSE=1568.11, R²=-2.022, Accuracy=87.20%

# %%
# General correlation analysis (all violations) for a specific place
import seaborn as sns

# Filter by place only, include all violations
place_df = df[df['GEO'] == Place]

# Select features + target
features_and_target = [
    'Rate_per_100000_population',
    'Cleared_by_charge', 'Cleared_otherwise',
    'Percentage_contribution_to_the_Crime_Severity_Index_(CSI)',
    'Rate_adult_charged_per_100000_population_aged_18_years_and_over',
    'Rate_total_persons_charged_per_100000_population_aged_12_years_and_over',
    'Rate_youth_charged_per_100000_population_aged_12_to_17_years',
    'Rate_youth_not_charged_per_100000_population_aged_12_to_17_years',
    'Total_cleared', 'Total_adult_charged', 'Total_persons_charged',
    'Total_youth_charged', 'Total_youth_not_charged', 'Actual_incidents'
]

# Filter columns and drop any rows with missing values
corr_df = place_df[features_and_target].dropna()

# Compute correlation matrix
corr_matrix = corr_df.corr(numeric_only=True)

# Plot heatmap of features vs target only
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix[['Actual_incidents']].sort_values(by='Actual_incidents', ascending=False), 
            annot=True, cmap='coolwarm', cbar=True)
plt.title(f'Feature Correlation with Actual Incidents - {Place}')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Loop through each violation and show correlation heatmap
for vio in violations:
    filtered_df_corr = df[(df['GEO'] == Place) & (df['Violations'] == vio)]

    corr_df = filtered_df_corr[[
        'Rate_per_100000_population',
        'Cleared_by_charge', 'Cleared_otherwise',
        'Percentage_contribution_to_the_Crime_Severity_Index_(CSI)',
        'Rate_adult_charged_per_100000_population_aged_18_years_and_over',
        'Rate_total_persons_charged_per_100000_population_aged_12_years_and_over',
        'Rate_youth_charged_per_100000_population_aged_12_to_17_years',
        'Rate_youth_not_charged_per_100000_population_aged_12_to_17_years',
        'Total_cleared', 'Total_adult_charged', 'Total_persons_charged',
        'Total_youth_charged', 'Total_youth_not_charged', 'Actual_incidents'
    ]]

    correlation_matrix = corr_df.corr(numeric_only=True)

    plt.figure(figsize=(10, 6))
    sns.heatmap(
        correlation_matrix[['Actual_incidents']].sort_values(by='Actual_incidents', ascending=False),
        annot=True, cmap='coolwarm', cbar=True, vmin=-1, vmax=1
    )
    plt.title(f'Feature Correlation with Actual Incidents - {vio}')
    plt.tight_layout()
    plt.show()

# %%
# !pip install lightgbm
# !pip install xgboost
# !pip install matplotlib scikit-learn pandas


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from IPython.display import display

# Load dataset
df = pd.read_csv("Merged_Unemployment_Data.csv")

# Convert date column to datetime
df['REF_DATE'] = pd.to_datetime(df['REF_DATE'], format='%Y')
# REF_DATE as index
df.set_index('REF_DATE', inplace=True)

violations = [
    'Total robbery [160]',
    'Total property crime violations [200]',
    'Total theft under $5,000 (non-motor vehicle) [240]',
    'Total theft of motor vehicle [220]',
    'Total mischief [250]',
    'Total drug violations [401]',
    # 'Murder, first degree [1110]',
    # 'Murder, second degree [1120]',
    "Sexual assault, level 3, aggravated [1310]",
    'Abduction under age 14, by parent or guardian [1560]',
    'Criminal harassment [1625]'
]

Place = 'Ontario [35]'


def plot_combined_predictions(X_train_scaled, y_train, X_test_scaled, y_test, title_suffix, place_name):
    models = {
        "Random Forest": RandomForestRegressor(),
        "Decision Tree": DecisionTreeRegressor(random_state=42),
        # "Neural Net (MLP)": MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', max_iter=1000, random_state=42),
        "XGBoost": XGBRegressor(),
        # "LightGBM": LGBMRegressor(n_estimators=500, max_depth=7, learning_rate=0.05, num_leaves=31, min_child_samples=5),
        "Ridge Regression": Ridge(),
        "Elastic Net": ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42),
        "Extra Trees": ExtraTreesRegressor()
    }

    predictions = {}
    results = []  # Store metrics for table

    for name, model in models.items():
        model.fit(X_train_scaled, y_train.values.ravel())
        y_pred = model.predict(X_test_scaled)
        predictions[name] = pd.Series(y_pred, index=y_test.index)

        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test, y_pred)
        accuracy = 100 - (mae / np.mean(y_test) * 100)

        results.append({
            "Violation": title_suffix.split(' (')[0],
            "Model": name,
            "MAE": round(mae, 2),
            "MSE": round(mse, 2),
            "RMSE": round(rmse, 2),
            "R²": round(r2, 3),
            "Accuracy (%)": round(accuracy, 2)
        })

    # Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(y_train, label='Training Data')
    plt.plot(y_test, label='Actual Test Data', linewidth=2, color='black')
    for name, y_pred_series in predictions.items():
        plt.plot(y_pred_series, label=f'Predicted: {name}')

    plt.title(f'Combined Model Predictions - {title_suffix}')
    plt.suptitle(place_name)
    plt.xlabel('Year')
    plt.ylabel('Actual_incidents')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return results  # ← Return the metrics




all_results = []

for vio in violations:
    print(f"\n--- Evaluating: {vio} ---")
    
    filtered_df = df[(df['GEO'] == Place) & (df['Violations'] == vio)]
    y_full = filtered_df[['Actual_incidents']]
    X_full = filtered_df[[
        'Rate_per_100000_population',
        'Cleared_by_charge', 'Cleared_otherwise',
        'Percentage_contribution_to_the_Crime_Severity_Index_(CSI)',
        'Rate_adult_charged_per_100000_population_aged_18_years_and_over',
        'Rate_total_persons_charged_per_100000_population_aged_12_years_and_over',
        'Rate_youth_charged_per_100000_population_aged_12_to_17_years',
        'Rate_youth_not_charged_per_100000_population_aged_12_to_17_years',
        'Total_cleared', 'Total_adult_charged', 'Total_persons_charged',
        'Total_youth_charged', 'Total_youth_not_charged'
    ]]

    y_train3 = y_full['1998-01-01':'2019-12-31']
    y_test3 = y_full['2019-01-01':'2023-12-31']
    X_train = X_full['1998-01-01':'2019-12-31']
    X_test = X_full['2019-01-01':'2023-12-31']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    results = plot_combined_predictions(X_train_scaled, y_train3, X_test_scaled, y_test3,
                                        f"{vio} (Train till 2019, Test 2020–2023)", Place)
    all_results.extend(results)

# Final table of all results
df_results = pd.DataFrame(all_results)
df_results = df_results[['Violation', 'Model', 'MAE', 'MSE', 'RMSE', 'R²', 'Accuracy (%)']]



display(df_results)
df_results.to_csv("model_evaluation_summary_with_all_features.csv", index=False)
# Out:
# --- Evaluating: Total robbery [160] ---
# --- Evaluating: Total property crime violations [200] ---
# --- Evaluating: Total theft under $5,000 (non-motor vehicle) [240] ---
# --- Evaluating: Total theft of motor vehicle [220] ---
# --- Evaluating: Total mischief [250] ---
# --- Evaluating: Total drug violations [401] ---
# --- Evaluating: Sexual assault, level 3, aggravated [1310] ---
# --- Evaluating: Abduction under age 14, by parent or guardian [1560] ---
# --- Evaluating: Criminal harassment [1625] ---
#                                             Violation             Model  \
# 0                                 Total robbery [160]     Random Forest
# 1                                 Total robbery [160]     Decision Tree
# 2                                 Total robbery [160]           XGBoost
# 3                                 Total robbery [160]  Ridge Regression
# 4                                 Total robbery [160]       Elastic Net
# 5                                 Total robbery [160]       Extra Trees
# 6               Total property crime violations [200]     Random Forest
# 7               Total property crime violations [200]     Decision Tree
# 8               Total property crime violations [200]           XGBoost
# 9               Total property crime violations [200]  Ridge Regression
# 10              Total property crime violations [200]       Elastic Net
# 11              Total property crime violations [200]       Extra Trees
# 12                           Total theft under $5,000     Random Forest
# 13                           Total theft under $5,000     Decision Tree
# 14                           Total theft under $5,000           XGBoost
# 15                           Total theft under $5,000  Ridge Regression
# 16                           Total theft under $5,000       Elastic Net
# 17                           Total theft under $5,000       Extra Trees
# 18                 Total theft of motor vehicle [220]     Random Forest
# 19                 Total theft of motor vehicle [220]     Decision Tree
# 20                 Total theft of motor vehicle [220]           XGBoost
# 21                 Total theft of motor vehicle [220]  Ridge Regression
# 22                 Total theft of motor vehicle [220]       Elastic Net
# 23                 Total theft of motor vehicle [220]       Extra Trees
# 24                               Total mischief [250]     Random Forest
# 25                               Total mischief [250]     Decision Tree
# 26                               Total mischief [250]           XGBoost
# 27                               Total mischief [250]  Ridge Regression
# 28                               Total mischief [250]       Elastic Net
# 29                               Total mischief [250]       Extra Trees
# 30                        Total drug violations [401]     Random Forest
# 31                        Total drug violations [401]     Decision Tree
# 32                        Total drug violations [401]           XGBoost
# 33                        Total drug violations [401]  Ridge Regression
# 34                        Total drug violations [401]       Elastic Net
# 35                        Total drug violations [401]       Extra Trees
# 36         Sexual assault, level 3, aggravated [1310]     Random Forest
# 37         Sexual assault, level 3, aggravated [1310]     Decision Tree
# 38         Sexual assault, level 3, aggravated [1310]           XGBoost
# 39         Sexual assault, level 3, aggravated [1310]  Ridge Regression
# 40         Sexual assault, level 3, aggravated [1310]       Elastic Net
# 41         Sexual assault, level 3, aggravated [1310]       Extra Trees
# 42  Abduction under age 14, by parent or guardian ...     Random Forest
# 43  Abduction under age 14, by parent or guardian ...     Decision Tree
# 44  Abduction under age 14, by parent or guardian ...           XGBoost
# 45  Abduction under age 14, by parent or guardian ...  Ridge Regression
# 46  Abduction under age 14, by parent or guardian ...       Elastic Net
# 47  Abduction under age 14, by parent or guardian ...       Extra Trees
# 48                         Criminal harassment [1625]     Random Forest
# 49                         Criminal harassment [1625]     Decision Tree
# 50                         Criminal harassment [1625]           XGBoost
# 51                         Criminal harassment [1625]  Ridge Regression
# 52                         Criminal harassment [1625]       Elastic Net
# 53                         Criminal harassment [1625]       Extra Trees
#
#          MAE           MSE      RMSE      R²  Accuracy (%)
# 0     609.34  6.505819e+05    806.59   0.164         92.12
# 1     530.80  4.554588e+05    674.88   0.415         93.13
# 2     514.60  4.294489e+05    655.32   0.448         93.34
# 3     161.10  4.453728e+04    211.04   0.943         97.92
# 4     139.83  2.525035e+04    158.90   0.968         98.19
# 5     421.68  4.194987e+05    647.69   0.461         94.55
# 6   30502.64  1.627310e+09  40339.93  -0.314         92.03
# 7   30279.60  1.750055e+09  41833.66  -0.413         92.08
# 8   18410.56  7.416204e+08  27232.71   0.401         95.19
# 9   61494.28  4.582551e+09  67694.54  -2.700         83.92
# 10  85638.87  8.717016e+09  93364.96  -6.038         77.61
# 11  17650.04  8.532774e+08  29210.91   0.311         95.39
# 12  12384.28  2.029864e+08  14247.33   0.566         93.04
# 13   8821.20  1.466055e+08  12108.07   0.686         95.04
# 14   8196.48  1.255324e+08  11204.12   0.732         95.40
# 15  10853.86  1.458678e+08  12077.57   0.688         93.90
# 16  18556.13  4.604016e+08  21456.97   0.015         89.58
# 17  12578.31  2.158518e+08  14691.89   0.538         92.93
# 18   6942.75  9.507066e+07   9750.42  -0.444         77.88
# 19   2192.20  1.026631e+07   3204.11   0.844         93.02
# 20   5229.62  4.020735e+07   6340.93   0.389         83.34
# 21   4351.47  3.857737e+07   6211.07   0.414         86.14
# 22   7052.17  9.450824e+07   9721.53  -0.435         77.54
# 23   6636.01  8.447178e+07   9190.85  -0.283         78.86
# 24   1001.00  1.213249e+06   1101.48   0.597         98.19
# 25   2145.80  7.418043e+06   2723.61  -1.463         96.12
# 26   2199.04  8.236855e+06   2869.99  -1.735         96.03
# 27   7698.89  6.320283e+07   7950.02 -19.989         86.08
# 28   6406.57  4.489354e+07   6700.26 -13.909         88.42
# 29    809.82  9.146803e+05    956.39   0.696         98.54
# 30   5139.31  2.913165e+07   5397.37  -6.563         61.32
# 31   1648.60  5.297280e+06   2301.58  -0.375         87.59
# 32   1648.60  5.297283e+06   2301.58  -0.375         87.59
# 33   1142.99  1.532086e+06   1237.77   0.602         91.40
# 34   2430.99  6.166601e+06   2483.26  -0.601         81.71
# 35   1832.54  5.536521e+06   2352.98  -0.437         86.21
# 36      1.71  4.200000e+00      2.05   0.250         94.66
# 37      2.40  1.440000e+01      3.79  -1.571         92.50
# 38      3.61  1.872000e+01      4.33  -2.343         88.71
# 39      0.72  5.500000e-01      0.74   0.902         97.74
# 40      1.97  4.520000e+00      2.13   0.193         93.84
# 41      1.10  2.300000e+00      1.52   0.589         96.58
# 42      0.71  7.800000e-01      0.88   0.773         96.35
# 43      1.60  3.600000e+00      1.90  -0.047         91.75
# 44      0.75  1.030000e+00      1.02   0.700         96.14
# 45      2.29  6.750000e+00      2.60  -0.963         88.19
# 46      3.92  2.244000e+01      4.74  -5.523         79.80
# 47      0.77  8.100000e-01      0.90   0.765         96.01
# 48   1609.81  3.153506e+06   1775.81  -2.876         84.42
# 49   1386.40  2.682988e+06   1637.98  -2.298         86.58
# 50   1145.37  1.874942e+06   1369.29  -1.304         88.92
# 51    623.53  4.130595e+05    642.70   0.492         93.97
# 52   1473.92  2.312040e+06   1520.54  -1.842         85.74
# 53   1301.88  2.376649e+06   1541.64  -1.921         87.40

# %%
# Filter the DataFrame for the selected violations
filtered_df = df[df['Violations'].isin(violations)]

# Count the number of records per violation
violation_counts = filtered_df['Violations'].value_counts().reset_index()
violation_counts.columns = ['Violation', 'Number_of_Records']

# Display the result
print(violation_counts)
# Out:
#                                            Violation  Number_of_Records
# 0  Abduction under age 14, by parent or guardian ...               1227
# 1                         Criminal harassment [1625]               1227
# 2         Sexual assault, level 3, aggravated [1310]               1227
# 3                        Total drug violations [401]               1227
# 4                               Total mischief [250]               1227
# 5              Total property crime violations [200]               1227
# 6                                Total robbery [160]               1227
# 7                 Total theft of motor vehicle [220]               1227
# 8  Total theft under $5,000 (non-motor vehicle) [...               1227
